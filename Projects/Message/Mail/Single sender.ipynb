# %% [markdown]
# # **MESSAGE SENDER**

# %%
import pandas as pd
import csv
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import tkinter as tk
from tkinter import messagebox
from tkinter import *

headlabelfont = ("Noto Sans CJK TC", 15, 'bold')
labelfont = ('Garamond', 14)
entryfont = ('Garamond', 12)

# SMTP Server
smtp_server = 'smtp-relay.sendinblue.com'
smtp_port = 587
smtp_username = 'sgtest.analogica@gmail.com'
smtp_password = 'Vgfs5k42FHdzUh3O'

# Connect to the SMTP server
smtp_connection = smtplib.SMTP(smtp_server, smtp_port)
smtp_connection.starttls()
smtp_connection.login(smtp_username, smtp_password)

# Initialize the tkinter window
window = tk.Tk()
window.title("Certisured Email Sender")
window.geometry('1000x600')
window.resizable(0, 0)

lf_bg = 'MediumSpringGreen'

tk.Label(window, text="MESSAGE SENDER", font=headlabelfont, bg='SpringGreen').pack(side=TOP, fill=X)

Frame(window, bg=lf_bg)

# Sender email label and entry field
sender_frame = Frame(window, bg=lf_bg)
sender_frame.pack(side=TOP, padx=5, pady=5, fill=X)

sender_label = tk.Label(sender_frame, text="Sender Email:", font=labelfont, bg=lf_bg)
sender_label.pack(side=LEFT)

sender_entry = tk.Entry(sender_frame, width=90, font=entryfont)
sender_entry.pack(side=LEFT, padx=5, pady=5, fill=X)
#sender_entry.insert(0, 'sameerpasha658@gmail.com')

# Sender email label and entry field
reciver_frame = Frame(window, bg=lf_bg)
reciver_frame.pack(side=TOP, padx=5, pady=5, fill=X)

reciver_label = tk.Label(reciver_frame, text="Reciver Gmail:", font=labelfont, bg=lf_bg)
reciver_label.pack(side=LEFT)

reciver_entry = tk.Entry(reciver_frame, width=90, font=entryfont)
reciver_entry.pack(side=LEFT, padx=5, pady=5, fill=X)

# Email subject label and entry field
subject_frame = Frame(window, bg=lf_bg)
subject_frame.pack(side=TOP, padx=5, pady=5, fill=X)

subject_label = tk.Label(subject_frame, text="Email subject:", font=labelfont, bg=lf_bg)
subject_label.pack(side=LEFT)

subject_entry = tk.Entry(subject_frame, width=90, font=entryfont)
subject_entry.pack(side=LEFT, padx=5, pady=5, fill=X)
#subject_entry.insert(0, 'I love Certisured')


# Email body label and text area
body_frame = Frame(window, bg=lf_bg)
body_frame.pack(side=TOP, padx=5, pady=5, fill=X)

body_label = tk.Label(body_frame, text="Email body:", font=labelfont, bg=lf_bg)
body_label.grid(row=0, column=0, padx=5, pady=5, sticky=W)

body_text = tk.Text(body_frame, width=105, height=15, font=entryfont)
body_text.grid(row=1, column=0, padx=5, pady=5, sticky=W)
#body_text.insert(tk.END, 'Hello {name}, this is from Certisured')


# Create a frame widget for the buttons
button_frame = tk.Frame(window)
button_frame.pack(side=tk.BOTTOM, pady=10)

# Send button
send_button = tk.Button(button_frame, text="Send", command=lambda: send_emails(), width=15, font=labelfont)
send_button.grid(row=0, column=0, padx=5, pady=5, sticky=W)

def clear_fields():
    # Clear the sender email, email subject, and email body fields
    sender_entry.delete(0, tk.END)
    reciver_entry.delete(0, tk.END)
    subject_entry.delete(0, tk.END)
    body_text.delete('1.0', tk.END)
    
# Clear button
clear_button = tk.Button(button_frame, text="Clear", command=lambda: clear_fields(), width=15, font=labelfont)
clear_button.grid(row=0, column=1, padx=5, pady=5, sticky=E)

def send_emails():
    # Get the sender email and email subject from the entry fields
    sender_email = sender_entry.get()
    reciver_gmail = reciver_entry.get()
    email_subject = subject_entry.get()
    
    # Create the email message
    msg = MIMEMultipart()
    msg['From'] = sender_email
    msg['To'] = reciver_gmail
    msg['Subject'] = email_subject
        
    # Set the email body
    email_body = body_text.get('1.0', tk.END)
    msg.attach(MIMEText(email_body, 'plain'))

    # Send the email
    smtp_connection.sendmail(sender_email, reciver_gmail, msg.as_string())
           
    # Close the SMTP connection             
    #smtp_connection.quit()
    
    # Show a message box indicating the emails have been sent
    tk.messagebox.showinfo("Emails sent", "Emails have been sent!")
    
# Run the tkinter event loop
window.mainloop()

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
import tkinter.messagebox as messagebox
    
    
# SMTP Server
smtp_server = 'smtp-relay.sendinblue.com'
smtp_port = 587
smtp_username = 'sgtest.analogica@gmail.com'
smtp_password = 'Vgfs5k42FHdzUh3O'

# Connect to the SMTP server
smtp_connection = smtplib.SMTP(smtp_server, smtp_port)
smtp_connection.starttls()
smtp_connection.login(smtp_username, smtp_password)

# Get the sender email and email subject from the entry fields
sender_email = "sameerpasha658@gmail.com"
receiver_email = "sameerpash658@gmail.com"
email_subject = "Welcome to Certisured"
    
# Sending a respective course video
name = "samer pasha"
course = "Machine Learning Engineer"
if course == "Machine Learning Engineer":
    course_link = "https://www.youtube.com/watch?v=uROL4HMfiCM&t=3s"  # Replace with the actual course link
elif course == "Python for Machine Learning":
    course_link = "https://www.youtube.com/watch?v=uROL4HMfiCM&t=1s"  # Replace with the actual course link
elif course == "Full Stack Data Analyst":
    course_link = "https://www.youtube.com/watch?v=uROL4HMfiCM"  # Replace with the actual course link
else:
    course_link = "https://certisured.com/"  # Replace with the actual course link

# Create the email message
msg = MIMEMultipart()
msg['From'] = sender_email
msg['To'] = receiver_email
msg['Subject'] = email_subject

# Set the email body
email_body = f'Hello {name}, this is from Certisured. Here is the link to your respective course: {course_link}'
msg.attach(MIMEText(email_body, 'plain'))

# Attach the PDF file
pdf_file_path = r"d:\Machine learning\PDF\grokking-machine-learning-meap-v07.pdf"# Replace with the actual path to your PDF file
attachment = open(pdf_file_path, 'rb')
part = MIMEBase('application', 'octet-stream')
part.set_payload((attachment).read())
encoders.encode_base64(part)
part.add_header('Content-Disposition', 'attachment', filename=pdf_file_path)
msg.attach(part)

# Send the email
smtp_connection.sendmail(sender_email, receiver_email, msg.as_string())

smtp_connection.quit()
# Out:
# (221, b'Bye')

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
import tkinter.messagebox as messagebox

# SMTP Server
smtp_server = 'smtp-relay.sendinblue.com'
smtp_port = 587
smtp_username = 'sgtest.analogica@gmail.com'
smtp_password = 'Vgfs5k42FHdzUh3O'

# Connect to the SMTP server
smtp_connection = smtplib.SMTP(smtp_server, smtp_port)
smtp_connection.starttls()
smtp_connection.login(smtp_username, smtp_password)

# Get the sender email and email subject from the entry fields
sender_email = "sameerpasha658@gmail.com"
receiver_email = "sameerpash658@gmail.com"
email_subject = "Welcome to Certisured"

# Sending a respective course video
name = "samer pasha"
course = "Machine Learning Engineer"
if course == "Machine Learning Engineer":
    course_link = "https://www.youtube.com/watch?v=uROL4HMfiCM&t=3s"  # Replace with the actual course link
elif course == "Python for Machine Learning":
    course_link = "https://www.youtube.com/watch?v=uROL4HMfiCM&t=1s"  # Replace with the actual course link
elif course == "Full Stack Data Analyst":
    course_link = "https://www.youtube.com/watch?v=uROL4HMfiCM"  # Replace with the actual course link
else:
    course_link = "https://certisured.com/"  # Replace with the actual course link

# Create the email message
msg = MIMEMultipart()
msg['From'] = sender_email
msg['To'] = receiver_email
msg['Subject'] = email_subject

# Set the email body
email_body = f'Hello {name}, this is from Certisured. Here is the link to your respective course: {course_link}'
msg.attach(MIMEText(email_body, 'plain'))

# Attach the file
file_path = r"C:\Users\Admin\OneDrive\Documents\Computer\Presentation1.pptx"  # Replace with the actual path to your file
attachment = open(file_path, 'rb')
part = MIMEBase('application', 'octet-stream')
part.set_payload((attachment).read())
encoders.encode_base64(part)
file_name = "CustomFileName.ext"  # Replace with the desired file name
part.add_header('Content-Disposition', 'attachment', filename=file_name)
msg.attach(part)

# Send the email
smtp_connection.sendmail(sender_email, receiver_email, msg.as_string())

smtp_connection.quit()
# Out:
# (221, b'Bye')
